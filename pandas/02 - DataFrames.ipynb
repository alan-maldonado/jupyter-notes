# %%
import numpy as np
import pandas as pd

from pandas import Series,DataFrame

# %%
import webbrowser
website='https://ratings.fide.com/top.phtml?list=men'
webbrowser.open(website)

# %%
chess_frame = pd.read_clipboard()

# %%
chess_frame.head(5)
# Out:
#    Rank                      Name Title Country  Rating  Games  B-Year
# 0     1           Carlsen, Magnus     g     NOR    2838      0    1990
# 1     2                So, Wesley     g     USA    2822      0    1993
# 2     3          Caruana, Fabiano     g     USA    2817     10    1992
# 3     4         Kramnik, Vladimir     g     RUS    2811      0    1975
# 4     5   Vachier-Lagrave, Maxime     g     FRA    2803     19    1990

# %%
chess_frame.columns
# Out:
# Index([u'Rank', u'Name', u'Title', u'Country', u'Rating', u'Games', u'B-Year'], dtype='object')

# %%
chess_frame.Name.head(5)
# Out:
# 0             Carlsen, Magnus
# 1                  So, Wesley
# 2            Caruana, Fabiano
# 3           Kramnik, Vladimir
# 4     Vachier-Lagrave, Maxime
# Name: Name, dtype: object

# %%
chess_frame['Rating'].head(5)
# Out:
# 0    2838
# 1    2822
# 2    2817
# 3    2811
# 4    2803
# Name: Rating, dtype: int64

# %%
DataFrame(chess_frame,columns=['Rank','Name','Title','Country','Rating','Games','B-Year']).head()
# Out:
#    Rank                      Name Title Country  Rating  Games  B-Year
# 0     1           Carlsen, Magnus     g     NOR    2838      0    1990
# 1     2                So, Wesley     g     USA    2822      0    1993
# 2     3          Caruana, Fabiano     g     USA    2817     10    1992
# 3     4         Kramnik, Vladimir     g     RUS    2811      0    1975
# 4     5   Vachier-Lagrave, Maxime     g     FRA    2803     19    1990

# %%
chess_frame = DataFrame(chess_frame,columns=['Rank','Name','Title','Country','Rating','Games','B-Year', 'Aux'])
chess_frame.head(3)
# Out:
#    Rank               Name Title Country  Rating  Games  B-Year  Aux
# 0     1    Carlsen, Magnus     g     NOR    2838      0    1990  NaN
# 1     2         So, Wesley     g     USA    2822      0    1993  NaN
# 2     3   Caruana, Fabiano     g     USA    2817     10    1992  NaN

# %%
chess_frame.head()
# Out:
#    Rank                      Name Title Country  Rating  Games  B-Year  Aux
# 0     1           Carlsen, Magnus     g     NOR    2838      0    1990  NaN
# 1     2                So, Wesley     g     USA    2822      0    1993  NaN
# 2     3          Caruana, Fabiano     g     USA    2817     10    1992  NaN
# 3     4         Kramnik, Vladimir     g     RUS    2811      0    1975  NaN
# 4     5   Vachier-Lagrave, Maxime     g     FRA    2803     19    1990  NaN

# %%
chess_frame.tail()
# Out:
#     Rank                  Name Title Country  Rating  Games  B-Year  Aux
# 95    96          Amin, Bassem     g     EGY    2660      1    1988  NaN
# 96    97     Ipatov, Alexander     g     TUR    2660      0    1993  NaN
# 97    98   Tkachiev, Vladislav     g     FRA    2660      0    1973  NaN
# 98    99          Kamsky, Gata     g     USA    2659     10    1974  NaN
# 99   100        Najer, Evgeniy     g     RUS    2659      0    1977  NaN

# %%
chess_frame.ix[0]
# Out:
# Rank                      1
# Name        Carlsen, Magnus
# Title                     g
# Country                 NOR
# Rating                 2838
# Games                     0
# B-Year                 1990
# Aux                     NaN
# Name: 0, dtype: object

# %%
chess_frame['Aux'] = "hi there"

# %%
chess_frame
# Out:
#     Rank                          Name Title Country  Rating  Games  B-Year  \
# 0      1               Carlsen, Magnus     g     NOR    2838      0    1990
# 1      2                    So, Wesley     g     USA    2822      0    1993
# 2      3              Caruana, Fabiano     g     USA    2817     10    1992
# 3      4             Kramnik, Vladimir     g     RUS    2811      0    1975
# 4      5       Vachier-Lagrave, Maxime     g     FRA    2803     19    1990
# 5      6              Nakamura, Hikaru     g     USA    2793     19    1987
# 6      7            Anand, Viswanathan     g     IND    2786      0    1969
# 7      8              Karjakin, Sergey     g     RUS    2783      0    1990
# 8      9                Aronian, Levon     g     ARM    2774      9    1982
# 9     10        Mamedyarov, Shakhriyar     g     AZE    2772      9    1985
# 10    11                   Giri, Anish     g     NED    2769      0    1994
# ...

# %%
chess_frame['Aux'] = np.arange(100)

# %%
chess_frame.head()
# Out:
#    Rank                      Name Title Country  Rating  Games  B-Year  Aux
# 0     1           Carlsen, Magnus     g     NOR    2838      0    1990    0
# 1     2                So, Wesley     g     USA    2822      0    1993    1
# 2     3          Caruana, Fabiano     g     USA    2817     10    1992    2
# 3     4         Kramnik, Vladimir     g     RUS    2811      0    1975    3
# 4     5   Vachier-Lagrave, Maxime     g     FRA    2803     19    1990    4

# %%
months = Series(['January','March'], index=[4,0])

# %%
months
# Out:
# 4    January
# 0      March
# dtype: object

# %%
chess_frame['Aux'] = months

# %%
chess_frame.head()
# Out:
#    Rank                      Name Title Country  Rating  Games  B-Year  \
# 0     1           Carlsen, Magnus     g     NOR    2838      0    1990
# 1     2                So, Wesley     g     USA    2822      0    1993
# 2     3          Caruana, Fabiano     g     USA    2817     10    1992
# 3     4         Kramnik, Vladimir     g     RUS    2811      0    1975
# 4     5   Vachier-Lagrave, Maxime     g     FRA    2803     19    1990
#
#        Aux
# 0    March
# 1      NaN
# 2      NaN
# 3      NaN
# 4  January

# %%
del chess_frame['Aux']
chess_frame
# Out:
#     Rank                          Name Title Country  Rating  Games  B-Year
# 0      1               Carlsen, Magnus     g     NOR    2838      0    1990
# 1      2                    So, Wesley     g     USA    2822      0    1993
# 2      3              Caruana, Fabiano     g     USA    2817     10    1992
# 3      4             Kramnik, Vladimir     g     RUS    2811      0    1975
# 4      5       Vachier-Lagrave, Maxime     g     FRA    2803     19    1990
# 5      6              Nakamura, Hikaru     g     USA    2793     19    1987
# 6      7            Anand, Viswanathan     g     IND    2786      0    1969
# 7      8              Karjakin, Sergey     g     RUS    2783      0    1990
# 8      9                Aronian, Levon     g     ARM    2774      9    1982
# 9     10        Mamedyarov, Shakhriyar     g     AZE    2772      9    1985
# 10    11                   Giri, Anish     g     NED    2769      0    1994
# ...

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
